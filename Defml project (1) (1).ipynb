# %%
import pandas as pd

# %%
df=pd.read_csv("depression.csv")

# %%
df
# Out:
#                 Country  Year Age Group     Sex  Currently_Drink_Alcohol  \
# 0             Argentina  2018     13-15  Female                     50.3
# 1             Argentina  2018     13-15    Male                     44.9
# 2             Argentina  2018     16-17  Female                     67.2
# 3             Argentina  2018     16-17    Male                     68.1
# 4             Argentina  2012     13-15    Male                     49.3
# ..                  ...   ...       ...     ...                      ...
# 101            Vanuatu   2011     13-15  Female                      5.8
# 102  Wallis and Futuna   2015     13-15    Male                     32.2
# 103  Wallis and Futuna   2015     13-15  Female                     24.4
# 104  Wallis and Futuna   2015     16-17    Male                     48.3
# 105  Wallis and Futuna   2015     16-17  Female                     42.9
#
#      Really_Get_Drunk  Overwieght  Use_Marijuana  Smoke_cig_currently  \
# ...

# %% [raw]
# ## Extraction of first five rows

# %%
df.head(5)
# Out:
#      Country  Year Age Group     Sex  Currently_Drink_Alcohol  \
# 0  Argentina  2018     13-15  Female                     50.3
# 1  Argentina  2018     13-15    Male                     44.9
# 2  Argentina  2018     16-17  Female                     67.2
# 3  Argentina  2018     16-17    Male                     68.1
# 4  Argentina  2012     13-15    Male                     49.3
#
#    Really_Get_Drunk  Overwieght  Use_Marijuana  Smoke_cig_currently  \
# 0              30.7        27.8            7.9                 16.8
# 1              26.1        39.1            8.4                 12.1
# 2              56.3        22.5           21.9                 28.5
# 3              55.8        27.9           27.0                 28.0
# 4              28.9        35.9           10.6                 17.0
#
#    Had_fights  No_close_friends  depression level
# 0        17.2               4.8                 0
# 1        33.2               5.5                 1
# ...

# %% [raw]
# ## Extraction of last five rows

# %%
df.tail(5)
# Out:
#                 Country  Year Age Group     Sex  Currently_Drink_Alcohol  \
# 101            Vanuatu   2011     13-15  Female                      5.8
# 102  Wallis and Futuna   2015     13-15    Male                     32.2
# 103  Wallis and Futuna   2015     13-15  Female                     24.4
# 104  Wallis and Futuna   2015     16-17    Male                     48.3
# 105  Wallis and Futuna   2015     16-17  Female                     42.9
#
#      Really_Get_Drunk  Overwieght  Use_Marijuana  Smoke_cig_currently  \
# 101               4.7        13.6            1.9                  8.2
# 102              35.5        60.5            4.0                 25.7
# 103              27.1        63.0            2.0                 29.9
# 104              53.7        57.8           10.1                 40.0
# 105              51.7        70.6            3.9                 41.7
#
#      Had_fights  No_close_friends  depression level
# 101        41.8              14.3                 0
# ...

# %%
df[45:]
# Out:
#                 Country  Year Age Group     Sex  Currently_Drink_Alcohol  \
# 45             Malaysia  2012     16-17  Female                      7.4
# 46             Mauritus  2017     13-15    Male                     20.2
# 47             Mauritus  2017     13-15  Female                     21.2
# 48             Mauritus  2017     16-17    Male                     40.1
# 49             Mauritus  2017     16-17  Female                     29.6
# ..                  ...   ...       ...     ...                      ...
# 101            Vanuatu   2011     13-15  Female                      5.8
# 102  Wallis and Futuna   2015     13-15    Male                     32.2
# 103  Wallis and Futuna   2015     13-15  Female                     24.4
# 104  Wallis and Futuna   2015     16-17    Male                     48.3
# 105  Wallis and Futuna   2015     16-17  Female                     42.9
#
#      Really_Get_Drunk  Overwieght  Use_Marijuana  Smoke_cig_currently  \
# ...

# %% [raw]
# ## Extraction of rows in b/w  some range

# %%
df[50:60]
# Out:
#      Country  Year Age Group     Sex  Currently_Drink_Alcohol  \
# 50  Mongolia  2013     13-15    Male                      4.9
# 51  Mongolia  2013     13-15  Female                      3.9
# 52  Mongolia  2013     16-17    Male                     23.2
# 53  Mongolia  2013     16-17  Female                     13.0
# 54  Mongolia  2010     13-15    Male                      6.6
# 55  Mongolia  2010     13-15  Female                      4.5
# 56   Namibia  2013     13-15    Male                     26.4
# 57   Namibia  2013     13-15  Female                     21.4
# 58   Namibia  2013     16-17    Male                     42.2
# 59   Namibia  2013     16-17  Female                     34.9
#
#     Really_Get_Drunk  Overwieght  Use_Marijuana  Smoke_cig_currently  \
# 50               8.5        11.3            1.5                  8.3
# 51               4.7        11.7            0.9                  3.3
# 52              32.6         6.3            2.2                 26.9
# ...

# %% [raw]
# ## accesing rows and columns by location based method (loc)

# %%
df.loc[1:5]
# Out:
#      Country  Year Age Group     Sex  Currently_Drink_Alcohol  \
# 1  Argentina  2018     13-15    Male                     44.9
# 2  Argentina  2018     16-17  Female                     67.2
# 3  Argentina  2018     16-17    Male                     68.1
# 4  Argentina  2012     13-15    Male                     49.3
# 5  Argentina  2012     13-15  Female                     50.7
#
#    Really_Get_Drunk  Overwieght  Use_Marijuana  Smoke_cig_currently  \
# 1              26.1        39.1            8.4                 12.1
# 2              56.3        22.5           21.9                 28.5
# 3              55.8        27.9           27.0                 28.0
# 4              28.9        35.9           10.6                 17.0
# 5              26.8        21.8            6.5                 20.5
#
#    Had_fights  No_close_friends  depression level
# 1        33.2               5.5                 1
# 2        15.1               6.3                 1
# ...

# %%
df.loc[:20]
# Out:
#                 Country  Year Age Group     Sex  Currently_Drink_Alcohol  \
# 0             Argentina  2018     13-15  Female                     50.3
# 1             Argentina  2018     13-15    Male                     44.9
# 2             Argentina  2018     16-17  Female                     67.2
# 3             Argentina  2018     16-17    Male                     68.1
# 4             Argentina  2012     13-15    Male                     49.3
# 5             Argentina  2012     13-15  Female                     50.7
# 6             Barabados  2011     13-15    Male                     29.4
# 7             Barabados  2011     13-15  Female                     26.6
# 8                 Benin  2016     13-15    Male                     38.0
# 9                 Benin  2016     13-15  Female                     42.4
# 10                Benin  2016     16-17    Male                     46.5
# 11                Benin  2016     16-17  Female                     36.1
# ...

# %%
df.loc[20,'Country']
# Out:
# 'Dominican Republic '

# %%
df.loc[3:16,['Country','Sex']]
# Out:
#                Country     Sex
# 3            Argentina    Male
# 4            Argentina    Male
# 5            Argentina  Female
# 6            Barabados    Male
# 7            Barabados  Female
# 8                Benin    Male
# 9                Benin  Female
# 10               Benin    Male
# 11               Benin  Female
# 12              Bhutan    Male
# 13              Bhutan  Female
# 14              Bhutan    Male
# 15              Bhutan  Female
# 16  Brunei Darussalam     Male

# %% [raw]
# ## Accessing rows and columns by iloc

# %%
df.iloc[1:5,1:4]
# Out:
#    Year Age Group     Sex
# 1  2018     13-15    Male
# 2  2018     16-17  Female
# 3  2018     16-17    Male
# 4  2012     13-15    Male

# %%
df.iloc[:10,:6]
# Out:
#      Country  Year Age Group     Sex  Currently_Drink_Alcohol  \
# 0  Argentina  2018     13-15  Female                     50.3
# 1  Argentina  2018     13-15    Male                     44.9
# 2  Argentina  2018     16-17  Female                     67.2
# 3  Argentina  2018     16-17    Male                     68.1
# 4  Argentina  2012     13-15    Male                     49.3
# 5  Argentina  2012     13-15  Female                     50.7
# 6  Barabados  2011     13-15    Male                     29.4
# 7  Barabados  2011     13-15  Female                     26.6
# 8      Benin  2016     13-15    Male                     38.0
# 9      Benin  2016     13-15  Female                     42.4
#
#    Really_Get_Drunk
# 0              30.7
# 1              26.1
# 2              56.3
# 3              55.8
# 4              28.9
# 5              26.8
# 6              80.2
# 7              78.0
# 8              19.3
# 9              16.8

# %%
df.iloc[[2,4,6,],[2,4,6]]
# Out:
#   Age Group  Currently_Drink_Alcohol  Overwieght
# 2     16-17                     67.2        22.5
# 4     13-15                     49.3        35.9
# 6     13-15                     29.4        32.3

# %%
df.shape
# Out:
# (106, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106 entries, 0 to 105
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country                  106 non-null    object
#  1   Year                     106 non-null    int64
#  2   Age Group                106 non-null    object
#  3   Sex                      106 non-null    object
#  4   Currently_Drink_Alcohol  106 non-null    float64
#  5   Really_Get_Drunk         106 non-null    float64
#  6   Overwieght               106 non-null    float64
#  7   Use_Marijuana            106 non-null    float64
#  8   Smoke_cig_currently      104 non-null    float64
#  9   Had_fights               106 non-null    float64
#  10  No_close_friends         106 non-null    float64
#  11  depression level         106 non-null    int64
# dtypes: float64(7), int64(2), object(3)
# memory usage: 10.1+ KB

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 101    False
# 102    False
# 103    False
# 104    False
# 105    False
# Length: 106, dtype: bool

# %%
df.describe()
# Out:
#               Year  Currently_Drink_Alcohol  Really_Get_Drunk  Overwieght  \
# count   106.000000               106.000000        106.000000  106.000000
# mean   2014.698113                31.815094         22.496226   23.694340
# std       2.089292                53.454089         16.553129   15.764075
# min    2010.000000                 1.400000          0.800000    3.300000
# 25%    2013.000000                11.550000          9.000000   11.400000
# 50%    2015.000000                26.000000         19.650000   21.800000
# 75%    2016.000000                42.350000         30.475000   31.850000
# max    2018.000000               548.000000         80.200000   70.600000
#
#        Use_Marijuana  Smoke_cig_currently  Had_fights  No_close_friends  \
# count     106.000000           104.000000  106.000000        106.000000
# mean        7.642453            15.546154   32.448113          7.744340
# std         8.713536            10.748501   15.297701          4.365254
# ...

# %%
df.ndim
# Out:
# 2

# %%
df.sample()
# Out:
#   Country  Year Age Group   Sex  Currently_Drink_Alcohol  Really_Get_Drunk  \
# 8   Benin  2016     13-15  Male                     38.0              19.3
#
#    Overwieght  Use_Marijuana  Smoke_cig_currently  Had_fights  \
# 8        12.7            0.8                  5.1        32.1
#
#    No_close_friends  depression level
# 8              10.8                 0

# %%
df.dtypes
# Out:
# Country                     object
# Year                         int64
# Age Group                   object
# Sex                         object
# Currently_Drink_Alcohol    float64
# Really_Get_Drunk           float64
# Overwieght                 float64
# Use_Marijuana              float64
# Smoke_cig_currently        float64
# Had_fights                 float64
# No_close_friends           float64
# depression level             int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Age Group', 'Sex', 'Currently_Drink_Alcohol',
#        'Really_Get_Drunk', 'Overwieght', 'Use_Marijuana',
#        'Smoke_cig_currently', 'Had_fights', 'No_close_friends',
#        'depression level'],
#       dtype='object')

# %%
df['Sex']
# Out:
# 0      Female
# 1        Male
# 2      Female
# 3        Male
# 4        Male
#         ...
# 101    Female
# 102      Male
# 103    Female
# 104      Male
# 105    Female
# Name: Sex, Length: 106, dtype: object

# %%
df.nunique()
# Out:
# Country                    27
# Year                        9
# Age Group                   2
# Sex                         2
# Currently_Drink_Alcohol    95
# Really_Get_Drunk           90
# Overwieght                 91
# Use_Marijuana              81
# Smoke_cig_currently        92
# Had_fights                 96
# No_close_friends           68
# depression level            2
# dtype: int64

# %%
df.count()
# Out:
# Country                    106
# Year                       106
# Age Group                  106
# Sex                        106
# Currently_Drink_Alcohol    106
# Really_Get_Drunk           106
# Overwieght                 106
# Use_Marijuana              106
# Smoke_cig_currently        104
# Had_fights                 106
# No_close_friends           106
# depression level           106
# dtype: int64

# %%
df.corr()
# Out:
#                              Year  Currently_Drink_Alcohol  Really_Get_Drunk  \
# Year                     1.000000                 0.188742          0.091310
# Currently_Drink_Alcohol  0.188742                 1.000000          0.311971
# Really_Get_Drunk         0.091310                 0.311971          1.000000
# Overwieght               0.087593                 0.037212          0.191082
# Use_Marijuana            0.168638                 0.318670          0.604226
# Smoke_cig_currently     -0.002162                 0.141118          0.584109
# Had_fights              -0.233693                 0.036944          0.052409
# No_close_friends         0.132952                 0.131297          0.206292
# depression level         0.120184                -0.023816          0.225129
#
#                          Overwieght  Use_Marijuana  Smoke_cig_currently  \
# Year                       0.087593       0.168638            -0.002162
# ...

# %%
df[['Sex','Year']]
# Out:
#         Sex  Year
# 0    Female  2018
# 1      Male  2018
# 2    Female  2018
# 3      Male  2018
# 4      Male  2012
# ..      ...   ...
# 101  Female  2011
# 102    Male  2015
# 103  Female  2015
# 104    Male  2015
# 105  Female  2015
#
# [106 rows x 2 columns]

# %%
df[df['Year']>2011]
# Out:
#                 Country  Year Age Group     Sex  Currently_Drink_Alcohol  \
# 0             Argentina  2018     13-15  Female                     50.3
# 1             Argentina  2018     13-15    Male                     44.9
# 2             Argentina  2018     16-17  Female                     67.2
# 3             Argentina  2018     16-17    Male                     68.1
# 4             Argentina  2012     13-15    Male                     49.3
# ..                  ...   ...       ...     ...                      ...
# 99             Vanuatu   2016     16-17  Female                     20.9
# 102  Wallis and Futuna   2015     13-15    Male                     32.2
# 103  Wallis and Futuna   2015     13-15  Female                     24.4
# 104  Wallis and Futuna   2015     16-17    Male                     48.3
# 105  Wallis and Futuna   2015     16-17  Female                     42.9
#
#      Really_Get_Drunk  Overwieght  Use_Marijuana  Smoke_cig_currently  \
# ...

# %%
df[df['Year']>2011].head(5)
# Out:
#      Country  Year Age Group     Sex  Currently_Drink_Alcohol  \
# 0  Argentina  2018     13-15  Female                     50.3
# 1  Argentina  2018     13-15    Male                     44.9
# 2  Argentina  2018     16-17  Female                     67.2
# 3  Argentina  2018     16-17    Male                     68.1
# 4  Argentina  2012     13-15    Male                     49.3
#
#    Really_Get_Drunk  Overwieght  Use_Marijuana  Smoke_cig_currently  \
# 0              30.7        27.8            7.9                 16.8
# 1              26.1        39.1            8.4                 12.1
# 2              56.3        22.5           21.9                 28.5
# 3              55.8        27.9           27.0                 28.0
# 4              28.9        35.9           10.6                 17.0
#
#    Had_fights  No_close_friends  depression level
# 0        17.2               4.8                 0
# 1        33.2               5.5                 1
# ...

# %%
df[df['Year']>2011].loc[4:8]
# Out:
#      Country  Year Age Group     Sex  Currently_Drink_Alcohol  \
# 4  Argentina  2012     13-15    Male                     49.3
# 5  Argentina  2012     13-15  Female                     50.7
# 8      Benin  2016     13-15    Male                     38.0
#
#    Really_Get_Drunk  Overwieght  Use_Marijuana  Smoke_cig_currently  \
# 4              28.9        35.9           10.6                 17.0
# 5              26.8        21.8            6.5                 20.5
# 8              19.3        12.7            0.8                  5.1
#
#    Had_fights  No_close_friends  depression level
# 4        44.2               6.1                 0
# 5        24.7               4.3                 1
# 8        32.1              10.8                 0

# %%
df[df['Year']>2011].loc[4:8,['Year','Sex']]
# Out:
#    Year     Sex
# 4  2012    Male
# 5  2012  Female
# 8  2016    Male

# %%
df[df['Year']>2011].iloc[1:5,2:9]
# Out:
#   Age Group     Sex  Currently_Drink_Alcohol  Really_Get_Drunk  Overwieght  \
# 1     13-15    Male                     44.9              26.1        39.1
# 2     16-17  Female                     67.2              56.3        22.5
# 3     16-17    Male                     68.1              55.8        27.9
# 4     13-15    Male                     49.3              28.9        35.9
#
#    Use_Marijuana  Smoke_cig_currently
# 1            8.4                 12.1
# 2           21.9                 28.5
# 3           27.0                 28.0
# 4           10.6                 17.0

# %%
df.isna().sum()
# Out:
# Country                    0
# Year                       0
# Age Group                  0
# Sex                        0
# Currently_Drink_Alcohol    0
# Really_Get_Drunk           0
# Overwieght                 0
# Use_Marijuana              0
# Smoke_cig_currently        2
# Had_fights                 0
# No_close_friends           0
# depression level           0
# dtype: int64

# %%
df.dropna()
# Out:
#                 Country  Year Age Group     Sex  Currently_Drink_Alcohol  \
# 0             Argentina  2018     13-15  Female                     50.3
# 1             Argentina  2018     13-15    Male                     44.9
# 2             Argentina  2018     16-17  Female                     67.2
# 3             Argentina  2018     16-17    Male                     68.1
# 4             Argentina  2012     13-15    Male                     49.3
# ..                  ...   ...       ...     ...                      ...
# 101            Vanuatu   2011     13-15  Female                      5.8
# 102  Wallis and Futuna   2015     13-15    Male                     32.2
# 103  Wallis and Futuna   2015     13-15  Female                     24.4
# 104  Wallis and Futuna   2015     16-17    Male                     48.3
# 105  Wallis and Futuna   2015     16-17  Female                     42.9
#
#      Really_Get_Drunk  Overwieght  Use_Marijuana  Smoke_cig_currently  \
# ...

# %%
d=df.dropna(axis=0)

# %%
df.shape
# Out:
# (106, 12)

# %%
d.shape
# Out:
# (104, 12)

# %%
df
# Out:
#                 Country  Year Age Group     Sex  Currently_Drink_Alcohol  \
# 0             Argentina  2018     13-15  Female                     50.3
# 1             Argentina  2018     13-15    Male                     44.9
# 2             Argentina  2018     16-17  Female                     67.2
# 3             Argentina  2018     16-17    Male                     68.1
# 4             Argentina  2012     13-15    Male                     49.3
# ..                  ...   ...       ...     ...                      ...
# 101            Vanuatu   2011     13-15  Female                      5.8
# 102  Wallis and Futuna   2015     13-15    Male                     32.2
# 103  Wallis and Futuna   2015     13-15  Female                     24.4
# 104  Wallis and Futuna   2015     16-17    Male                     48.3
# 105  Wallis and Futuna   2015     16-17  Female                     42.9
#
#      Really_Get_Drunk  Overwieght  Use_Marijuana  Smoke_cig_currently  \
# ...

# %%
df.fillna(0)
# Out:
#                 Country  Year Age Group     Sex  Currently_Drink_Alcohol  \
# 0             Argentina  2018     13-15  Female                     50.3
# 1             Argentina  2018     13-15    Male                     44.9
# 2             Argentina  2018     16-17  Female                     67.2
# 3             Argentina  2018     16-17    Male                     68.1
# 4             Argentina  2012     13-15    Male                     49.3
# ..                  ...   ...       ...     ...                      ...
# 101            Vanuatu   2011     13-15  Female                      5.8
# 102  Wallis and Futuna   2015     13-15    Male                     32.2
# 103  Wallis and Futuna   2015     13-15  Female                     24.4
# 104  Wallis and Futuna   2015     16-17    Male                     48.3
# 105  Wallis and Futuna   2015     16-17  Female                     42.9
#
#      Really_Get_Drunk  Overwieght  Use_Marijuana  Smoke_cig_currently  \
# ...

# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

# %%
df.head(5)
# Out:
#      Country  Year Age Group     Sex  Currently_Drink_Alcohol  \
# 0  Argentina  2018     13-15  Female                     50.3
# 1  Argentina  2018     13-15    Male                     44.9
# 2  Argentina  2018     16-17  Female                     67.2
# 3  Argentina  2018     16-17    Male                     68.1
# 4  Argentina  2012     13-15    Male                     49.3
#
#    Really_Get_Drunk  Overwieght  Use_Marijuana  Smoke_cig_currently  \
# 0              30.7        27.8            7.9                 16.8
# 1              26.1        39.1            8.4                 12.1
# 2              56.3        22.5           21.9                 28.5
# 3              55.8        27.9           27.0                 28.0
# 4              28.9        35.9           10.6                 17.0
#
#    Had_fights  No_close_friends  depression level
# 0        17.2               4.8                 0
# 1        33.2               5.5                 1
# ...

# %%
df=df.rename({'Sex':'Gender','Age Group':'Age'},axis=1)

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Age', 'Gender', 'Currently_Drink_Alcohol',
#        'Really_Get_Drunk', 'Overwieght', 'Use_Marijuana',
#        'Smoke_cig_currently', 'Had_fights', 'No_close_friends',
#        'depression level'],
#       dtype='object')

# %%
print(df.Gender.value_counts())
df.Gender.value_counts().plot.bar()
# Out:
# Female    53
# Male      53
# Name: Gender, dtype: int64
# <AxesSubplot:>

# %%
print(df.Age.value_counts())
# Out:
# 13-15    62
# 16-17    44
# Name: Age, dtype: int64

# %%
df.Age.value_counts().plot.barh()
# Out:
# <AxesSubplot:>

# %%
df.Smoke_cig_currently.value_counts()
# Out:
# 9.7     3
# 17.1    2
# 12.6    2
# 1.5     2
# 12.1    2
#        ..
# 19.5    1
# 34.3    1
# 14.0    1
# 20.7    1
# 41.7    1
# Name: Smoke_cig_currently, Length: 92, dtype: int64

# %%
df.Smoke_cig_currently.value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(9,9))
plt.title('Age wise Analysis')
plt.xlabel("Age Group")
plt.ylabel("Smoke_cig_currently")
plt.bar(df.Age,df.Smoke_cig_currently)
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(9,9))
sns.barplot(x='Gender',y='Smoke_cig_currently',data=df,palette="Blues")
plt.title('Gender wise Analysis')
plt.xlabel("Gender")
plt.ylabel("Smoke_cig_currently")
plt.show()

# %%
sns.barplot(x='Age',y='Smoke_cig_currently',hue='depression level',data=df,palette="Blues")
plt.title('Age wise Analysis')
plt.xlabel("Age")
plt.ylabel("Smoke_cig_currently")
plt.show()

# %%
df.Age.hist()
# Out:
# <AxesSubplot:>

# %%
df.Age.hist(bins=2)
# Out:
# <AxesSubplot:>

# %%
df.hist(column='Age',by="depression level",bins =12)
# Out:
# array([<AxesSubplot:title={'center':'0'}>,
#        <AxesSubplot:title={'center':'1'}>], dtype=object)

# %%
plt.title('Drugs wise Analysis')
plt.xlabel("Use_Marijuana")
plt.ylabel("Smoke_cig_currently")
plt.scatter(df.Gender,df.Smoke_cig_currently)
plt.show()

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Age', 'Gender', 'Currently_Drink_Alcohol',
#        'Really_Get_Drunk', 'Overwieght', 'Use_Marijuana',
#        'Smoke_cig_currently', 'Had_fights', 'No_close_friends',
#        'depression level'],
#       dtype='object')

# %%
sns.scatterplot(x='Age',y='Smoke_cig_currently',hue='depression level',data=df,palette="Blues")
plt.title('Age wise Analysis')
plt.xlabel("Age")
plt.ylabel("Smoke_cig_currently")
plt.show()

# %%
df.Smoke_cig_currently.plot.area()
# Out:
# <AxesSubplot:>

# %%
df.Smoke_cig_currently.plot.box()
# Out:
# <AxesSubplot:>

# %%
df.Smoke_cig_currently.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.boxenplot(x='Age',y='Smoke_cig_currently',hue='depression level',data=df,palette="Blues")
plt.title('Age wise Analysis')
plt.xlabel("Age")
plt.ylabel("Smoke_cig_currently")
plt.show()

# %%
sns.catplot(x='Age',y='Smoke_cig_currently',hue='depression level',data=df,palette="Blues")
plt.title('Age wise Analysis')
plt.xlabel("Age")
plt.ylabel("Smoke_cig_currently")
plt.show()

# %%
sns.heatmap(df[['depression level','Smoke_cig_currently']])
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.corr(),annot=True,cmap='Reds')
# Out:
# <AxesSubplot:>

# %%
df.count().plot.barh()
# Out:
# <AxesSubplot:>

# %%
df.plot.area()
# Out:
# <AxesSubplot:>

# %%
pip install empiricaldist
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000229D6F5A280>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/empiricaldist/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000229D6F5A130>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/empiricaldist/
# ...

# %%
from empiricaldist import pmf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\SINGIR~1\AppData\Local\Temp/ipykernel_13668/4012000530.py in <module>
# ----> 1 from empiricaldist import pmf
#
# ModuleNotFoundError: No module named 'empiricaldist'
